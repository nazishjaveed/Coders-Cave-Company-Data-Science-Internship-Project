# %% [markdown]
# # <h1 style="background-color:#42EADDFF;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:Black;">Customer Behaviour Analysis On Transaction Data</h1>

# %% [markdown]
# ![](https://media.gettyimages.com/id/1184048369/photo/woman-is-shopping-in-supermarket-and-scanning-barcode-with-smartphone.jpg?s=612x612&w=0&k=20&c=Chvm-dp_pUoCp_21RVIwxPbUR3tHN2HeiKBQrg8SCKA=)

# %% [markdown]
# # <h1 style="background-color:#42EADDFF;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:Black;"> Overview Of The Customer Behaviour Analysis Project</h1>

# %% [markdown]
# #### 🎯 Project Objective
#
# The primary objective of this project is to perform an in-depth Exploratory Data Analysis (EDA) to understand and analyze customer behavior based on transactional data. The analysis aims to derive valuable insights into customer preferences, purchasing patterns, and overall behavior to inform business strategies and enhance decision-making.
#
# #### 🗂️ Data Description
#
# The dataset, which can be found [here](https://www.kaggle.com/path/to/your/dataset), consists of transactional data with the following columns:
# - **📅 MONTH**: The month when the transaction occurred.
# - **🏬 STORECODE**: The code representing the store where the transaction took place.
# - **📦 QTY**: Quantity of items purchased in the transaction.
# - **💰 VALUE**: Monetary value of the transaction.
# - **📁 GRP**: General category of the product purchased.
# - **🗂️ SGRP**: Sub-category of the product.
# - **📂 SSGRP**: Sub-sub-category of the product.
# - **📢 CMP**: Campaign or promotion associated with the transaction.
# - **🆔 MBRD**: Membership ID of the customer making the transaction.
# - **🏷️ BRD**: Brand of the product purchased.
#
# #### 📝 Project Steps
#
# 1. **🔍 Data Understanding and Cleaning**
#    - Familiarize with the dataset and understand the meaning of each column.
#    - Clean the data by handling missing values, removing duplicates, and ensuring appropriate data types for each column.
#
# 2. **📈 Data Exploration**
#    - Generate basic statistics to understand the dataset's structure.
#    - Analyze the distribution of transaction values and quantities.
#    - Examine monthly trends and seasonal patterns in transactions.
#
# 3. **🧩 Customer Segmentation**
#    - Identify top customers based on the number of transactions and total spending.
#    - Segment customers into different groups based on their purchase frequency and transaction value.
#
# 4. **🔍 Insights and Patterns**
#    - Perform product analysis to identify popular products, brand performance, and the effectiveness of promotional campaigns.
#    - Compare sales performance across different stores to identify top-performing and under-performing locations.
#    - Analyze the purchasing behavior of repeat customers and their preferences for specific product categories.
#
# 5. **📊 Visualization**
#    - Create time series plots to visualize monthly sales and quantity trends.
#    - Use bar charts to depict the top products by sales value and quantity, as well as sales performance by store and campaign.
#    - Generate heatmaps to explore correlations between numerical variables and visualize customer segments.
#
# 6. **📋 Reporting**
#    - Compile a summary report highlighting key findings and insights from the analysis.
#    - Develop interactive dashboards using tools like Tableau or Power BI for ongoing monitoring of customer behavior and sales performance.
#
# #### 🌟 Expected Outcomes
#
# By completing this project, the business will gain a comprehensive understanding of customer behavior, including:
# - Customer preferences for different products and brands.
# - The impact of promotional campaigns on sales.
# - Seasonal trends and monthly sales patterns.
# - Performance metrics for different stores.
# - Detailed segmentation of customers based on their purchasing habits.
#
# These insights will enable data-driven decision-making, helping to optimize marketing strategies, improve inventory management, enhance customer retention efforts, and ultimately drive business growth. 🚀

# %% [markdown]
# # <h1 style="background-color:#42EADDFF;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:Black;">Contact With Me</h1>

# %% [markdown]
# [![GitHub](https://img.shields.io/badge/GitHub-Profile-blue?style=for-the-badge&logo=github)](https://github.com/nazishjaveed)
#
# [![Kaggle](https://img.shields.io/badge/Kaggle-Profile-blue?style=for-the-badge&logo=kaggle)](https://www.kaggle.com/nazishjaveed)
#
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-Profile-blue?style=for-the-badge&logo=linkedin)](https://www.linkedin.com/in/nazish-javeed-395461271/)

# %% [markdown]
# # <h1 style="background-color:#42EADDFF;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:Black;">Set-1 Import Library</h1>

# %%
import pandas as pd

# %% [markdown]
# # <h1 style="background-color:#42EADDFF;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:Black;">Step-2 Import Dataset</h1>

# %%
# Load the data
data = pd.read_csv('/kaggle/input/store-transaction-dataset/Store Transaction Data.csv')

# %% [markdown]
# # <h1 style="background-color:#42EADDFF;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:Black;"> Srep-3 Data Preprocessing And Cleaning</h1>

# %% [markdown]
# ### 3.1 Data Cleaning

# %%
# Check for duplicates
duplicates = data.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 0

# %%
# Drop duplicates
data.drop_duplicates(inplace=True)

# %%
# Check for missing values
missing_values = data.isnull().sum()
print("Missing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# MONTH        0
# STORECODE    0
# QTY          0
# VALUE        0
# GRP          0
# SGRP         0
# SSGRP        0
# CMP          0
# MBRD         0
# BRD          0
# dtype: int64

# %%
# Fill missing values (example: forward fill method)
data.fillna(method='ffill', inplace=True)
# Out:
# /tmp/ipykernel_18/3717599171.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)

# %%
# Ensure data types are correct
data.dtypes
# Out:
# MONTH        object
# STORECODE    object
# QTY           int64
# VALUE         int64
# GRP          object
# SGRP         object
# SSGRP        object
# CMP          object
# MBRD         object
# BRD          object
# dtype: object

# %% [markdown]
# ### 3.2 Data Transformation

# %%
# Create a new feature: Total transaction value
data['TOTAL_VALUE'] = data['QTY'] * data['VALUE']

# %% [markdown]
# # <h1 style="background-color:#42EADDFF;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:Black;">Step-4 Exploratory DataAnalysis (EDA)</h1>

# %% [markdown]
# ### 4.1 Descriptive Statistics

# %%
# Descriptive statistics
data.describe()
# Out:
#                 QTY         VALUE   TOTAL_VALUE
# count  14260.000000  14260.000000  1.426000e+04
# mean      16.354488    294.455330  1.458708e+04
# std       34.365583    760.129558  1.066462e+05
# min        0.000000      0.000000  0.000000e+00
# 25%        1.000000     10.000000  1.700000e+01
# 50%        4.000000     99.000000  4.770000e+02
# 75%       16.000000    283.000000  4.181000e+03
# max      641.000000  24185.000000  7.303870e+06

# %% [markdown]
# ### 4.2 Distribution Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot distribution of QTY
plt.figure(figsize=(10, 5))
sns.histplot(data['QTY'], bins=30, kde=True)
plt.title('Quantity Distribution')
plt.xlabel('Quantity')
plt.ylabel('Frequency')
plt.show()

# Plot distribution of VALUE
plt.figure(figsize=(10, 5))
sns.histplot(data['VALUE'], bins=30, kde=True)
plt.title('Value Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### 4.3 Time Series Analysis

# %%
# Aggregate data by month
monthly_sales = data.groupby('MONTH').agg({'QTY': 'sum', 'VALUE': 'sum'}).reset_index()

# Plot monthly quantity trend
plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly_sales, x='MONTH', y='QTY', marker='o')
plt.title('Monthly Quantity Trend')
plt.xlabel('Month')
plt.ylabel('Total Quantity')
plt.show()

# Plot monthly value trend
plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly_sales, x='MONTH', y='VALUE', marker='o')
plt.title('Monthly Value Trend')
plt.xlabel('Month')
plt.ylabel('Total Value')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ###  4.4 Store Analysis

# %%
# Aggregate data by store
store_performance = data.groupby('STORECODE').agg({'QTY': 'sum', 'VALUE': 'sum'}).reset_index()

# Plot store performance by value
plt.figure(figsize=(12, 6))
sns.barplot(data=store_performance, x='STORECODE', y='VALUE')
plt.title('Store Performance by Value')
plt.xlabel('Store Code')
plt.ylabel('Total Value')
plt.show()

# %% [markdown]
# ### 4.5 Product Analysis

# %%
# Aggregate data by product group
grp_performance = data.groupby('GRP').agg({'QTY': 'sum', 'VALUE': 'sum'}).reset_index()

# Plot product group performance by value
plt.figure(figsize=(12, 6))
sns.barplot(data=grp_performance, x='GRP', y='VALUE')
plt.title('Product Group Performance by Value')
plt.xlabel('Product Group')
plt.ylabel('Total Value')
plt.show()

# %% [markdown]
# ### 4.6 Campaign Analysis

# %%
# Aggregate data by campaign
cmp_performance = data.groupby('CMP').agg({'QTY': 'sum', 'VALUE': 'sum'}).reset_index()

# Plot campaign performance by value
plt.figure(figsize=(12, 6))
sns.barplot(data=cmp_performance, x='CMP', y='VALUE')
plt.title('Campaign Performance by Value')
plt.xlabel('Campaign')
plt.ylabel('Total Value')
plt.show()

# %% [markdown]
# ### 4.7 Customer Segmentation

# %%
# Aggregate data by membership
mbrd_performance = data.groupby('MBRD').agg({'QTY': 'sum', 'VALUE': 'sum'}).reset_index()

# Plot loyalty program performance by value
plt.figure(figsize=(12, 6))
sns.barplot(data=mbrd_performance, x='MBRD', y='VALUE')
plt.title('Loyalty Program Performance by Value')
plt.xlabel('Membership')
plt.ylabel('Total Value')
plt.show()

# %% [markdown]
# ### 4.8 Brand Analysis

# %%
# Aggregate data by brand
brd_performance = data.groupby('BRD').agg({'QTY': 'sum', 'VALUE': 'sum'}).reset_index()

# Plot brand performance by value
plt.figure(figsize=(12, 6))
sns.barplot(data=brd_performance, x='BRD', y='VALUE')
plt.title('Brand Performance by Value')
plt.xlabel('Brand')
plt.ylabel('Total Value')
plt.show()

# %% [markdown]
# # <h1 style="background-color:#42EADDFF;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:Black;">Step-5 Insights And Recommendation</h1>

# %% [markdown]
# ### 5.1 Summarize Key Findings

# %%
# Overall Sales Trends
monthly_sales_summary = monthly_sales.describe()
print("Monthly Sales Summary:")
print(monthly_sales_summary)

# Store Performance Summary
store_performance_summary = store_performance.describe()
print("\nStore Performance Summary:")
print(store_performance_summary)

# Product Group Performance Summary
grp_performance_summary = grp_performance.describe()
print("\nProduct Group Performance Summary:")
print(grp_performance_summary)

# Campaign Performance Summary
cmp_performance_summary = cmp_performance.describe()
print("\nCampaign Performance Summary:")
print(cmp_performance_summary)

# Customer Segmentation Summary
mbrd_performance_summary = mbrd_performance.describe()
print("\nCustomer Segmentation Summary:")
print(mbrd_performance_summary)

# Brand Performance Summary
brd_performance_summary = brd_performance.describe()
print("\nBrand Performance Summary:")
print(brd_performance_summary)
# Out:
# Monthly Sales Summary:
#                 QTY         VALUE
# count      3.000000  3.000000e+00
# mean   77738.333333  1.399644e+06
# std      830.826296  1.251477e+04
# min    77042.000000  1.389256e+06
# 25%    77278.500000  1.392698e+06
# 50%    77515.000000  1.396139e+06
# 75%    78086.500000  1.404838e+06
# max    78658.000000  1.413538e+06
#
# Store Performance Summary:
#                 QTY          VALUE
# count     10.000000      10.000000
# mean   23321.500000  419893.300000
# std     6862.919289  132596.228673
# min    10483.000000  284024.000000
# 25%    20956.500000  318747.000000
# 50%    21250.500000  381818.000000
# 75%    27199.750000  494861.750000
# max    34089.000000  671988.000000
#
# Product Group Performance Summary:
#                 QTY          VALUE
# count     80.000000      80.000000
# mean    2915.187500   52486.662500
# std     6044.118482   86481.628002
# min        1.000000      22.000000
# 25%      181.750000    6320.750000
# ...

# %% [markdown]
# ### 5.2 Derive Actionable Insights

# %%
# Insights on High-Performing Stores
high_performing_stores = store_performance.sort_values(by='VALUE', ascending=False).head()
print("Top 5 High-Performing Stores by Value:")
print(high_performing_stores)

# Insights on Popular Product Categories
popular_product_groups = grp_performance.sort_values(by='VALUE', ascending=False).head()
print("\nTop 5 Popular Product Groups by Value:")
print(popular_product_groups)

# Insights on Campaign Success
successful_campaigns = cmp_performance.sort_values(by='VALUE', ascending=False).head()
print("\nTop 5 Successful Campaigns by Value:")
print(successful_campaigns)

# Insights on Customer Segmentation
loyalty_program_performance = mbrd_performance.sort_values(by='VALUE', ascending=False)
print("\nLoyalty Program Performance:")
print(loyalty_program_performance)

# Insights on Brand Performance
top_performing_brands = brd_performance.sort_values(by='VALUE', ascending=False).head()
print("\nTop 5 Performing Brands by Value:")
print(top_performing_brands)
# Out:
# Top 5 High-Performing Stores by Value:
#   STORECODE    QTY   VALUE
# 8        P8  32003  671988
# 7        P7  21114  571136
# 6        P6  21178  502627
# 4        P4  34089  471566
# 3        P3  27602  428550
#
# Top 5 Popular Product Groups by Value:
#                               GRP    QTY   VALUE
# 57  REFINED EDIBLE OILS-ALL PACKS   3108  502344
# 68                 SPICES (03/04)  25179  341116
# 10     BISCUITS - CORE & NON CORE  35375  324360
# 52                   PACKAGED TEA   7225  229186
# 72           TOILET SOAPS (04/00)   7298  212570
#
# Top 5 Successful Campaigns by Value:
#                             CMP    QTY   VALUE
# 174  HINDUSTAN UNILEVER LIMITED  46584  589463
# 292      MONDELEZ INTERNATIONAL  12769  192167
# 397            S NARENDRA KUMAR  11510  169364
# 351            PROCTER & GAMBLE  10399  161658
# 54               BRITANNIA INDS  13211  139910
#
# Loyalty Program Performance:
#                       MBRD    QTY   VALUE
# ...

# %% [markdown]
# ### 5.3 Provide Recommendations

# %%
# Recommendations based on insights

# 1. Improve Stock for High-Performing Stores
print("\nRecommendation 1: Improve Stock for High-Performing Stores")
print("Focus on maintaining sufficient inventory levels at top-performing stores to avoid stockouts and maximize sales opportunities.")

# 2. Focus on Popular Product Categories
print("\nRecommendation 2: Focus on Popular Product Categories")
print("Increase marketing efforts and stock levels for top product categories to meet customer demand and drive sales growth.")

# 3. Enhance Campaign Strategies
print("\nRecommendation 3: Enhance Campaign Strategies")
print("Analyze the characteristics of successful campaigns and replicate these strategies for future promotions to boost sales.")

# 4. Leverage Loyalty Programs
print("\nRecommendation 4: Leverage Loyalty Programs")
print("Encourage customer sign-ups for loyalty programs by offering exclusive benefits, which can help increase customer retention and repeat purchases.")

# 5. Promote Top-Performing Brands
print("\nRecommendation 5: Promote Top-Performing Brands")
print("Partner with top-performing brands for joint promotions and highlight these brands in marketing materials to attract more customers.")
# Out:
# Recommendation 1: Improve Stock for High-Performing Stores
# Focus on maintaining sufficient inventory levels at top-performing stores to avoid stockouts and maximize sales opportunities.
#
# Recommendation 2: Focus on Popular Product Categories
# Increase marketing efforts and stock levels for top product categories to meet customer demand and drive sales growth.
#
# Recommendation 3: Enhance Campaign Strategies
# Analyze the characteristics of successful campaigns and replicate these strategies for future promotions to boost sales.
#
# Recommendation 4: Leverage Loyalty Programs
# Encourage customer sign-ups for loyalty programs by offering exclusive benefits, which can help increase customer retention and repeat purchases.
#
# Recommendation 5: Promote Top-Performing Brands
# Partner with top-performing brands for joint promotions and highlight these brands in marketing materials to attract more customers.

# %% [markdown]
# # <h1 style="background-color:#42EADDFF;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:Black;">Detailed Explaination</h1>

# %% [markdown]
# ### Summarize Key Findings:
#
# * Calculate and print descriptive statistics for each key area of analysis (monthly sales, store performance, product groups, campaigns, customer segmentation, and brands).
# ### Derive Actionable Insights:
#
# * Identify top-performing stores, product categories, campaigns, customer segments (e.g., loyalty program members), and brands by sorting and displaying the top records.
# ### Provide Recommendations:
#
# * Based on the insights derived, provide actionable recommendations to improve business performance. Each recommendation targets a specific area such as inventory management, marketing, campaign strategy, customer retention, and brand promotion.
# This approach ensures that the insights gained from the EDA are translated into practical strategies that can be implemented to enhance customer satisfaction and drive sales growth.#

# %% [markdown]
# # <h1 style="background-color:#42EADDFF;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:Black;">The End</h1>
